# %% [markdown]
# # procedimiento para analizar la calidad de las secuencias con FastQC

# %% [markdown]
# # Las secuencias tienen adaptadores, los cuales debes ser removidos
# ## descargar el programa Trim_galore

# %% [markdown]
# https://www.bioinformatics.babraham.ac.uk/projects/trim_galore/
#
# <img src="img/trim_galore1.png" alt="The Filesystem" />

# %% [markdown]
# https://www.bioinformatics.babraham.ac.uk/projects/download.html#trim_galore
#
# <img src="img/trim_galore2.png" alt="The Filesystem" />

# %% [markdown]
# #### al final de la página

# %% [markdown]
# https://www.bioinformatics.babraham.ac.uk/projects/download.html#trim_galore
# <img src="img/trim_galore3.png" alt="The Filesystem" />

# %% [markdown]
# # Ejemplo de eliminación de adaptadores utilizando trim_galore
# ```!../../../../Desktop/analisis/scripts/trim_galore_v0/trim_galore \
# --paired \
# --retain_unpaired \
# datos/CC-1_S1_L001_R1_001.fastq \
# datos/CC-1_S1_L001_R2_001.fastq```

# %% [markdown]
# ## Una vez que se han eliminado los adaptadores, se procede a eliminar las regiones de baja calidad.
# # FastQC

# %% [markdown]
# http://www.bioinformatics.babraham.ac.uk/projects/fastqc/
# <img src="img/fastqc1.png" alt="The Filesystem" />

# %% [markdown]
# http://www.bioinformatics.babraham.ac.uk/projects/download.html#fastqc
# <img src="img/fastqc2.png" alt="The Filesystem" />

# %%
pwd
# Out:
# 'C:\\Users\\SalaD26\\Desktop\\jupyter'

# %%
cd ~/Desktop/data/ejercicio_fastqc/
# Out:
# C:\Users\SalaD26\Desktop\data\ejercicio_fastqc

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 4C69-5113
#
#  Directorio de C:\Users\SalaD26\Desktop\data\ejercicio_fastqc
#
# 23/07/2018  11:51 a. m.    <DIR>          .
# 23/07/2018  11:51 a. m.    <DIR>          ..
# 05/06/2013  12:12 p. m.         3,350,863 8_S356_L001_R1_001.fastq
# 05/06/2013  12:12 p. m.         3,364,073 8_S356_L001_R2_001.fastq
#                2 archivos      6,714,936 bytes
#                2 dirs  82,114,695,168 bytes libres

# %%
# !fastqc 8_S356_L001_R1_001.fastq
# Out:
# "fastqc" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%bash
# fastqc 8_S356_L001_R1_001.fastq
# fastqc 8_S356_L001_R2_001.fastq
# Out:
# Couldn't find program: 'bash'

# %% [markdown]
# ### Los resultados se visualizan abriendo el archivo *html* que se generó para cada archivo.fastq

# %% [markdown]
# # Para usuarios avanzados se da los siguientes comandos para visualizar los datos dentro de la bitácora sin necesidad de estar cambiando de pestañas

# %%
import os

# %%
os.makedirs('8_S356_fastqc',exist_ok=True)

# %%
cd 8_S356_fastqc
# Out:
# C:\Users\SalaD26\Desktop\data\ejercicio_fastqc\8_S356_fastqc

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 4C69-5113
#
#  Directorio de C:\Users\SalaD26\Desktop\data\ejercicio_fastqc\8_S356_fastqc
#
# 30/07/2018  09:34 a. m.    <DIR>          .
# 30/07/2018  09:34 a. m.    <DIR>          ..
#                0 archivos              0 bytes
#                2 dirs  82,108,018,688 bytes libres

# %%
from zipfile import ZipFile

# %%
# se descomrimen los archivos en el directorio
with ZipFile('./8_S356_L001_R1_001_fastqc.zip', 'r') as zf:
    zf.extractall('./')
with ZipFile('./8_S356_L001_R2_001_fastqc.zip', 'r') as zf:
    zf.extractall('./')

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 4C69-5113
#
#  Directorio de C:\Users\SalaD26\Desktop\jupyter
#
# 30/07/2018  09:00 a. m.    <DIR>          .
# 30/07/2018  09:00 a. m.    <DIR>          ..
# 30/07/2018  09:00 a. m.    <DIR>          .ipynb_checkpoints
# 27/07/2018  08:04 p. m.             5,247 00temario_win.ipynb
# 27/07/2018  08:25 p. m.               861 01markdown_win.ipynb
# 26/07/2018  12:23 p. m.           401,239 02_comandoslinux_win.ipynb
# 27/07/2018  09:40 p. m.            40,823 02_sistema_operativo_basico_win.ipynb
# 26/07/2018  12:23 p. m.           403,345 02_sistemaoperativo_win.ipynb
# 27/07/2018  09:14 p. m.             9,378 03_actualización_bases_datos_ncbi_win.ipynb
# 27/07/2018  10:52 a. m.            38,320 03_CpG_win.ipynb
# 10/01/2018  06:41 p. m.            44,984 07_1analisis_secuencias_ab1_win.ipynb
# 24/07/2018  08:10 p. m.           171,514 07_2blast_secuencias_win.ipynb
# 04/01/2018  12:34 p. m.             5,515 07_3alineamiento_win.ipynb
# 20/07/2018  01:03 p. m.            10,171 08_actualización_bases_datos_ncbi_win.ipynb
# 30/07/2018  09:00 a. m.           385,528 14fastqc.ipynb
# 30/07/2018  09:00 a. m.            13,066 14fastqc_win.ipynb
# 30/07/2018  08:57 a. m.    <DIR>          anotacion
# 30/07/2018  08:59 a. m.    <DIR>          img
#               13 archivos      1,529,991 bytes
#                5 dirs  82,662,469,632 bytes libres

# %% [markdown]
# <img src="8_S356_L001_R1_001_fastqc/Images/per_base_n_content.png">

# %% [markdown]
# <img src="./8_S356_L001_R1_001_fastqc/Images/per_base_quality.png",width=300,height=300>

# %%
ls 8_S356_L001_R1_001_fastqc/Images/
# Out:
# adapter_content.png            per_sequence_gc_content.png
# duplication_levels.png         per_sequence_quality.png
# per_base_n_content.png         per_tile_quality.png
# per_base_quality.png           sequence_length_distribution.png
# per_base_sequence_content.png

# %%
#import os
from IPython.display import display, Image

# %%
# ?Image

# %%
names = !ls 8_S356_L001_R1_001_fastqc/Images/*.png
names[:5]
# Out:
# ['8_S356_L001_R1_001_fastqc/Images/adapter_content.png',
#  '8_S356_L001_R1_001_fastqc/Images/duplication_levels.png',
#  '8_S356_L001_R1_001_fastqc/Images/per_base_n_content.png',
#  '8_S356_L001_R1_001_fastqc/Images/per_base_quality.png',
#  '8_S356_L001_R1_001_fastqc/Images/per_base_sequence_content.png']

# %%
for name in names:
    display(Image(name, width=300))

# %%
for name in names:
    display(Image(name, retina=True))

# %%
from PIL import Image
import PIL.ImageOps
import os
