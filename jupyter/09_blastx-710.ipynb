# %% [markdown]
# # Bitacora para el manejo de secuencias fasta y búsqueda basica de *Blastx*

# %% [markdown]
# ## Para el siguiente ejercicio es necesario tener el Blast+ instalado en la computadora
# https://www.ncbi.nlm.nih.gov/guide/data-software/

# %%
cd ~/Desktop/data/exp710/
# Out:
# /home/user1/Desktop/data/exp710

# %%
ls
# Out:
# 710_transcritos.fasta  710_transcritos.tab  core.29269

# %%
# %%bash
# export BLASTDB=/home/user1/DATA/swiss/
#
# date
# time blastx -query 710_transcritos.fasta -db /home/user1/DATA/swiss/swissprot \
# -out 710_transcritos.tab -evalue 1E-6 -max_target_seqs 1 \
# -num_threads 2 -outfmt "6 std stitle"
# date
# Out:
# Process is interrupted.

# %%
# !head 710_transcritos.tab
# Out:
# 1001070759	P46595.1	87.611	113	14	0	7	345	1	113	1.86e-66	199	RecName: Full=Ubiquitin-conjugating enzyme E2 4; AltName: Full=E2 ubiquitin-conjugating enzyme 4; AltName: Full=Ubiquitin carrier protein 4; AltName: Full=Ubiquitin-protein ligase 4
# 1001070758	Q9Y4A8.1	43.243	111	61	1	1031	1357	536	646	1.81e-14	80.1	RecName: Full=Nuclear factor erythroid 2-related factor 3; Short=NF-E2-related factor 3; Short=NFE2-related factor 3; AltName: Full=Nuclear factor, erythroid derived 2, like 3
# 1001070756	P22813.1	44.286	70	39	0	621	830	164	233	8.29e-14	75.1	RecName: Full=Heat shock factor protein; Short=HSF; AltName: Full=Heat shock transcription factor; Short=HSTF
# 1001070755	P02833.1	90.361	83	4	1	1185	1421	283	365	3.54e-41	157	RecName: Full=Homeotic protein antennapedia
# 1001070754	G5E8K5.1	25.131	382	203	13	434	1498	352	677	1.58e-12	76.3	RecName: Full=Ankyrin-3; Short=ANK-3; AltName: Full=Ankyrin-G
# 1001070754	G5E8K5.1	33.077	130	78	3	386	775	469	589	1.26e-10	70.1	RecName: Full=Ankyrin-3; Short=ANK-3; AltName: Full=Ankyrin-G
# 1001070754	G5E8K5.1	28.926	121	78	2	419	781	644	756	3.46e-07	58.9	RecName: Full=Ankyrin-3; Short=ANK-3; AltName: Full=Ankyrin-G
# 1001070754	G5E8K5.1	24.384	406	234	14	434	1486	253	640	3.82e-07	58.5	RecName: Full=Ankyrin-3; Short=ANK-3; AltName: Full=Ankyrin-G
# 1001070754	G5E8K5.1	29.508	122	78	2	416	781	544	657	8.82e-07	57.4	RecName: Full=Ankyrin-3; Short=ANK-3; AltName: Full=Ankyrin-G
# 1001070753	P05179.2	32.653	441	270	8	249	1520	58	488	1.06e-65	223	RecName: Full=Cytochrome P450 2C7; AltName: Full=CYPIIC7; AltName: Full=Cytochrome P450F; AltName: Full=PTF1

# %%
from pandas import Series, DataFrame
import pandas as pd
from Bio import SeqIO, AlignIO, SeqRecord
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import matplotlib.pyplot as plt 
import os
from matplotlib_venn import venn3_unweighted

# %% [markdown]
# ###  Blastx da los resultados sin nombre de columnas, por lo que se asignan a la variable "encabezado".
# ### *NOTA:* el blastx a la base de datos swissprot da como segunda columna el identificador de Uniprot y no el del GenBank como en el caso de blastn a la base de datos 16 microbial o nt

# %%
# observe el nombre de la segunda columna
encabezado =("qseqid", "uniprotid", "pident", "length", "mismatch", "gapopen","qstart", 
             "qend", "sstart","send", "evalue", "bitscore", "stitle")

# %% [markdown]
# ### Se lee el archivo de salida y se asigna a la variable "ftab", con ello se pueden ver los resultados

# %%
ftab=pd.read_table("710_transcritos.tab", header=None , names= encabezado)
ftab.head()
# Out:
#        qseqid uniprotid  pident  length  mismatch  gapopen  qstart  qend  \
# 0  1001070759  P46595.1  87.611     113        14        0       7   345
# 1  1001070758  Q9Y4A8.1  43.243     111        61        1    1031  1357
# 2  1001070756  P22813.1  44.286      70        39        0     621   830
# 3  1001070755  P02833.1  90.361      83         4        1    1185  1421
# 4  1001070754  G5E8K5.1  25.131     382       203       13     434  1498
#
#    sstart  send        evalue  bitscore  \
# 0       1   113  1.860000e-66     199.0
# 1     536   646  1.810000e-14      80.1
# 2     164   233  8.290000e-14      75.1
# 3     283   365  3.540000e-41     157.0
# 4     352   677  1.580000e-12      76.3
#
#                                               stitle
# 0  RecName: Full=Ubiquitin-conjugating enzyme E2 ...
# 1  RecName: Full=Nuclear factor erythroid 2-relat...
# 2  RecName: Full=Heat shock factor protein; Short...
# 3        RecName: Full=Homeotic protein antennapedia
# 4  RecName: Full=Ankyrin-3; Short=ANK-3; AltName:...

# %%
ftab1= ftab.groupby("stitle")["qseqid"].count()
ftab1 = DataFrame(ftab1)
ftab1
# Out:
#                                                     qseqid
# stitle
# RecName: Full=6-phosphofructo-2-kinase/fructose...       1
# RecName: Full=Akirin; AltName: Full=Protein bhr...       2
# RecName: Full=Alpha-crystallin A chain                   2
# RecName: Full=Alpha-crystallin B chain; AltName...       5
# RecName: Full=Ankyrin repeat and KH domain-cont...       7
# RecName: Full=Ankyrin repeat and KH domain-cont...      68
# RecName: Full=Ankyrin repeat domain-containing ...      13
# RecName: Full=Ankyrin repeat domain-containing ...     116
# RecName: Full=Ankyrin-1; Short=ANK-1; AltName: ...      15
# RecName: Full=Ankyrin-3; Short=ANK-3; AltName: ...      29
# RecName: Full=Apoptosis inhibitor IAP                    2
# RecName: Full=B-cell lymphoma 3 protein homolog...       1
# RecName: Full=Baculoviral IAP repeat-containing...       6
# RecName: Full=Baculoviral IAP repeat-containing...       1
# RecName: Full=Baculoviral IAP repeat-containing...       2
# RecName: Full=Breast cancer metastasis-suppress...       1
# RecName: Full=Caspase-1; Contains: RecName: Ful...       2
# RecName: Full=Caspase-2; Short=CASP-2; AltName:...       1
# RecName: Full=Cyclic AMP-responsive element-bin...       2
# RecName: Full=Cyclin-dependent kinase 6; AltNam...       1
# RecName: Full=Cytochrome P450 2B19; AltName: Fu...       1
# RecName: Full=Cytochrome P450 2C7; AltName: Ful...       1
# RecName: Full=Cytochrome P450 2J6; AltName: Ful...       1
# RecName: Full=Cytochrome P450 306a1; Short=CYPC...       1
# RecName: Full=Cytochrome P450 315a1, mitochondr...       1
# RecName: Full=Death-associated inhibitor of apo...       9
# RecName: Full=Endoplasmic reticulum chaperone B...       1
# RecName: Full=Endoplasmic reticulum chaperone B...       6
# RecName: Full=FACT complex subunit Ssrp1; AltNa...       1
# RecName: Full=FAS-associated factor 1; Short=hF...       2
# ...                                                    ...
# RecName: Full=NEDD8-conjugating enzyme UBE2F; A...       1
# RecName: Full=Neuronal membrane glycoprotein M6...       1
# RecName: Full=Nitric oxide synthase, salivary g...       1
# RecName: Full=Nuclear factor NF-kappa-B p110 su...       2
# RecName: Full=Nuclear factor erythroid 2-relate...       1
# RecName: Full=PR domain zinc finger protein 10;...       1
# RecName: Full=Probable maleylacetoacetate isome...       1
# RecName: Full=Protein PET100 homolog, mitochond...       4
# RecName: Full=Protein lethal(2)essential for li...       9
# RecName: Full=Putative ankyrin repeat protein R...       8
# RecName: Full=Putative glutaminase 2; Short=GLS...       4
# RecName: Full=Segmentation protein cap'n'collar          1
# RecName: Full=Serine/threonine-protein kinase C...       3
# RecName: Full=Serine/threonine-protein kinase P...       1
# RecName: Full=Serine/threonine-protein kinase P...       2
# RecName: Full=Serine/threonine-protein kinase T...      20
# RecName: Full=Serine/threonine-protein kinase U...       4
# RecName: Full=Serine/threonine-protein kinase m...       1
# RecName: Full=Stress-activated protein kinase J...       1
# RecName: Full=Transcription factor AP-1; AltNam...       3
# RecName: Full=Trithorax group protein osa; AltN...       6
# RecName: Full=Ubiquitin-conjugating enzyme E2 4...       1
# RecName: Full=Ubiquitin-conjugating enzyme E2 G...       1
# RecName: Full=Ubiquitin-conjugating enzyme E2 H...       1
# RecName: Full=Ubiquitin-conjugating enzyme E2 L...       3
# RecName: Full=Ubiquitin-conjugating enzyme E2 L...       1
# RecName: Full=Ubiquitin-conjugating enzyme E2 T...       2
# RecName: Full=Ubiquitin-conjugating enzyme E2-2...       1
# RecName: Full=Ubiquitin-conjugating enzyme E2-2...       1
# RecName: Full=Zinc finger protein 888                    1
#
# [93 rows x 1 columns]

# %%
ftab1 = ftab.drop_duplicates(subset = "qseqid", inplace = False)
ftab1.describe().round(3)
# Out:
#              qseqid   pident    length  mismatch  gapopen    qstart      qend  \
# count  2.300000e+02  230.000   230.000   230.000  230.000   230.000   230.000
# mean   1.001071e+09   51.128   285.765   127.791    3.470   841.191   748.113
# std    1.055110e+02   16.756   248.370   119.647    4.199  1006.605   706.577
# min    1.001070e+09   25.103    37.000     4.000    0.000     1.000     1.000
# 25%    1.001070e+09   36.352   110.000    45.250    1.000   123.750   276.000
# 50%    1.001071e+09   49.184   192.000    94.000    2.000   457.500   575.000
# 75%    1.001071e+09   63.090   353.500   157.500    4.000  1175.750   975.000
# max    1.001071e+09   90.361  1130.000   616.000   19.000  3575.000  4035.000
#
#          sstart      send  evalue  bitscore
# count   230.000   230.000   230.0   230.000
# mean    238.730   515.396     0.0   264.723
# std     482.784   514.793     0.0   231.177
# min       1.000    49.000     0.0    50.400
# 25%      11.000   196.000     0.0    81.600
# 50%      58.000   343.000     0.0   175.500
# 75%     199.750   635.000     0.0   339.250
# max    2302.000  2688.000     0.0   912.000

# %%
# !date
# Out:
# Thu Aug  2 20:33:29 UTC 2018

# %%
fspid = pd.read_csv('~/Desktop/bigdata/spidgo.csv', engine="python")
fspid.head(2)

# %%
# !date

# %%
f2=pd.merge(ftab1,fspid, on ="uniprotid" , how='inner')
f2.head(2)

# %%
fspid = ''
fspid

# %%
# !date

# %%
# !date

# %%
# !date
fgo = pd.read_csv('~/Desktop/bigdata/go_to_goslim.csv', engine="python")
fgo.head(2)

# %%
# !date

# %%
f3=pd.merge(f2,fgo, on ="GO_id" , how='inner')
f3.head()

# %%
# !date

# %%
f4=f3.drop_duplicates(subset = ('qseqid', "aspect"), inplace = False)
f4.describe()[['length','evalue']]

# %%
f4.to_csv("710_transcritos_goslim.csv", index =  None)

# %%
ftabpivot = f4.pivot_table(values="uniprotid" , index=["qseqid"], aggfunc=len, columns="aspect")
ftabpivot.describe()

# %% [markdown]
# # Proceso para generar el diagama de Venn con la información de
# ## Componentes celulares, funciones biologicas y procesos biologicos, C, F y P, respectivamente

# %%
lineaC =[] # data from C
lineaF =[] # data from F
lineaP =[] # data from P
linea = ""
n=1
for row in ftabpivot.index:
    row2=ftabpivot.loc[row]
    if str(row2["C"])=="nan" and str(row2["F"])=="nan" and str(row2["P"])=="nan" :
        continue    
    else:        
        if str(row2["C"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaC.append(linea)
        if str(row2["F"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaF.append(linea)

        if str(row2["P"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaP.append(linea)

        n+=1
        #if n==1000:
        #    break

len(lineaC), len(lineaF), len(lineaP)

# %%
lineaC = set(lineaC)
lineaF = set(lineaF)
lineaP = set(lineaP)
venn3_unweighted([lineaC, lineaF, lineaP], ('C', 'F', 'P'))
plt.savefig("710_transcritos_venn3_1.png", dpi=400, bbox_inches='tight')
plt.savefig("710_transcritos_venn3_1.pdf", dpi=400, bbox_inches='tight')
plt.show()

# %%
fgo=f4.groupby('GOSlim_bin')["qseqid"].count()
#fgo

fgo.sort_values(inplace = True, ascending=False)
#fgo

linea10=fgo[0:10]
linea11=fgo[10:]
#linea10

#linea11
otro=sum (linea11)
#otro
otros = pd.DataFrame({0:otro}, index=["Other"])
#otros
linea10=linea10.append(otros)
#linea10
linea10.plot(kind='barh', color=list('ybg'))
plt.axis([-1, 500, -1, 11], label=None)
plt.xlabel("Count")
plt.ylabel("GOSlim bin")
plt.legend().set_visible(False)
#plt.savefig("710transcritos_blastx_GObar.png", dpi=400, bbox_inches='tight')


plt.show()

# %% [markdown]
# # Escriba qué es lo que aprendió en esta bitácora y en qué le podría ayudar en su trabajo, sea tan explícito como le sea posible
