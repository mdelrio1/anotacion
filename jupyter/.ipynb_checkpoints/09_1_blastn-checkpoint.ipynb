# %% [markdown]
# # Bitacora para el manejo de secuencias ensambladas y búsqueda con *Blastn*

# %% [markdown]
# ## Para el siguiente ejercicio es necesario tener el Blast+ instalado en la computadora
# https://www.ncbi.nlm.nih.gov/guide/data-software/

# %% [markdown]
# ## Se utilizarán los contigs formados por el ensamblaje que se localizan en
# `~/Desktop/data/ejercicio_ensamblaje/8_S356_contigs.fa`

# %%
from pandas import Series, DataFrame
import pandas as pd
from Bio import SeqIO, AlignIO, SeqRecord
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import matplotlib.pyplot as plt

# %%
cd ~/Desktop/data/ejercicio_ensamblaje/
# Out:
# /home/user1/Desktop/data/ejercicio_ensamblaje

# %%
ls
# Out:
# 8_S356_contigs.fa          8_S356_contigs_blastx.tab         trinity/
# 8_S356_contigs.tab         8_S356_contigs_blastx_goslim.csv
# 8_S356_contigs_blastn.csv  img/

# %%
# !grep ">" 8_S356_contigs.fa |wc -l
# Out:
# 321

# %% [markdown]
# # se analizarán con blastx los contigs obtenidos

# %%
# %%bash
# export BLASTDB=/home/user1/DATA/nt/
#
# date
# time blastn -query 8_S356_contigs.fa  -db /home/user1/DATA/nt/nt \
# -out 8_S356_contigs.tab -evalue 1E-6 -max_target_seqs 1 \
# -num_threads 2 -outfmt "6 std sskingdoms stitle staxids sscinames scomnames sblastnames"
# date

# %%
# !date
# Out:
# Fri Aug  3 13:00:26 UTC 2018

# %%
# !head -2 8_S356_contigs.tab

# %%
encabezado =("qseqid", "sseqid", "pident", "length", "mismatch", "gapopen","qstart", 
             "qend", "sstart","send", "evalue", "bitscore", "sskingdoms", "stitle", 
             "staxids", "sscinames", "scomnames", "sblastnames")

# %%
ftab=pd.read_table("8_S356_contigs.tab", header=None , names= encabezado)
ftab.head()
# Out:
#                 qseqid          sseqid  pident  length  mismatch  gapopen  \
# 0  8_S356_contig000005  XR_001415659.1  90.385      52         5        0
# 1  8_S356_contig000008  XR_001428184.1  95.522     134         6        0
# 2  8_S356_contig000013  XM_004569909.4  78.676     136        19        7
# 3  8_S356_contig000014  XR_002665540.1  88.690     168        18        1
# 4  8_S356_contig000015      CP026258.1  89.394     264        21        5
#
#    qstart  qend    sstart      send        evalue  bitscore sskingdoms  \
# 0     311   362       885       834  1.160000e-07      69.4  Eukaryota
# 1      74   207        52       185  5.430000e-52     215.0  Eukaryota
# 2      85   212        78       211  2.720000e-11      82.4  Eukaryota
# 3     190   357       781       615  1.930000e-48     204.0  Eukaryota
# 4      70   326  13254129  13253866  3.560000e-85     326.0  Eukaryota
#
#                                               stitle staxids  \
# 0  PREDICTED: Poecilia mexicana uncharacterized L...   48701
# 1  PREDICTED: Poecilia latipinna uncharacterized ...   48699
# 2  PREDICTED: Maylandia zebra F-box protein 34 (f...  106582
# 3  PREDICTED: Seriola dumerili uncharacterized LO...   41447
# 4                 Scophthalmus maximus chromosome 16   52904
#
#               sscinames          scomnames  sblastnames
# 0     Poecilia mexicana  Poecilia mexicana  bony fishes
# 1    Poecilia latipinna      sailfin molly  bony fishes
# 2       Maylandia zebra        zebra mbuna  bony fishes
# 3      Seriola dumerili  greater amberjack  bony fishes
# 4  Scophthalmus maximus             turbot  bony fishes

# %%
len(ftab)
# Out:
# 242

# %%
ftab1= ftab.groupby("sskingdoms")["qseqid"].count()
ftab1 = DataFrame(ftab1)
ftab1
# Out:
#             qseqid
# sskingdoms
# Eukaryota      242

# %% [markdown]
# # Cuántos contigs no son eucariotas?

# %% [markdown]
# ## Guadardo la base de datos en formato csv

# %%
ftab.to_csv("8_S356_contigs_blastn.csv", header=True, index= None)

# %% [markdown]
# ### en caso de haber el hecho el análisis previo y querer recuperar el archivo anterior

# %%
ftab= pd.read_csv("8_S356_contigs_blastn.csv")
ftab.head(2)
# Out:
#                 qseqid          sseqid  pident  length  mismatch  gapopen  \
# 0  8_S356_contig000005  XR_001415659.1  90.385      52         5        0
# 1  8_S356_contig000008  XR_001428184.1  95.522     134         6        0
#
#    qstart  qend  sstart  send        evalue  bitscore sskingdoms  \
# 0     311   362     885   834  1.160000e-07      69.4  Eukaryota
# 1      74   207      52   185  5.430000e-52     215.0  Eukaryota
#
#                                               stitle staxids  \
# 0  PREDICTED: Poecilia mexicana uncharacterized L...   48701
# 1  PREDICTED: Poecilia latipinna uncharacterized ...   48699
#
#             sscinames          scomnames  sblastnames
# 0   Poecilia mexicana  Poecilia mexicana  bony fishes
# 1  Poecilia latipinna      sailfin molly  bony fishes

# %% [markdown]
# # Hay algún contig con más de una asignación (duplicados)?

# %%
ftab1= ftab.groupby("qseqid")["qseqid"].count()
ftab1 = DataFrame(ftab1)
ftab1
# Out:
#                      qseqid
# qseqid
# 8_S356_contig000005       1
# 8_S356_contig000008       1
# 8_S356_contig000013       1
# 8_S356_contig000014       1
# 8_S356_contig000015       3
# 8_S356_contig000016       1
# 8_S356_contig000017       1
# 8_S356_contig000018       1
# 8_S356_contig000020       1
# 8_S356_contig000021       1
# 8_S356_contig000022       1
# 8_S356_contig000023       1
# 8_S356_contig000024       1
# 8_S356_contig000025       1
# 8_S356_contig000026       1
# 8_S356_contig000027       2
# 8_S356_contig000028       1
# 8_S356_contig000033       1
# 8_S356_contig000034       1
# 8_S356_contig000035       1
# 8_S356_contig000036       1
# 8_S356_contig000037       1
# 8_S356_contig000038       1
# 8_S356_contig000039       1
# 8_S356_contig000040       1
# 8_S356_contig000041       1
# 8_S356_contig000042       1
# 8_S356_contig000044       1
# 8_S356_contig000046       1
# 8_S356_contig000047       1
# ...                     ...
# 8_S356_contig000251       1
# 8_S356_contig000252       1
# 8_S356_contig000253       1
# 8_S356_contig000254       3
# 8_S356_contig000255       1
# 8_S356_contig000258       1
# 8_S356_contig000266       1
# 8_S356_contig000272       1
# 8_S356_contig000274       1
# 8_S356_contig000275       2
# 8_S356_contig000278       1
# 8_S356_contig000281       1
# 8_S356_contig000283       1
# 8_S356_contig000284       1
# 8_S356_contig000287       1
# 8_S356_contig000291       1
# 8_S356_contig000292      25
# 8_S356_contig000295       1
# 8_S356_contig000296       1
# 8_S356_contig000297       1
# 8_S356_contig000301       1
# 8_S356_contig000303       1
# 8_S356_contig000307       1
# 8_S356_contig000308       1
# 8_S356_contig000309       1
# 8_S356_contig000313       1
# 8_S356_contig000314       1
# 8_S356_contig000315       1
# 8_S356_contig000320       1
# 8_S356_contig000321       1
#
# [148 rows x 1 columns]

# %% [markdown]
# # Es necesario eliminar duplicados

# %%
ftab1 =ftab.drop_duplicates(subset = 'qseqid', keep='first', inplace = False)
ftab1
# Out:
#                   qseqid          sseqid  pident  length  mismatch  gapopen  \
# 0    8_S356_contig000005  XR_001415659.1  90.385      52         5        0
# 1    8_S356_contig000008  XR_001428184.1  95.522     134         6        0
# 2    8_S356_contig000013  XM_004569909.4  78.676     136        19        7
# 3    8_S356_contig000014  XR_002665540.1  88.690     168        18        1
# 4    8_S356_contig000015      CP026258.1  89.394     264        21        5
# 7    8_S356_contig000016  XM_017411639.2  94.175     103         5        1
# 8    8_S356_contig000017  XM_017411639.2  85.556     270        30        7
# 9    8_S356_contig000018      AB649033.1  83.568     426        63        5
# 10   8_S356_contig000020      AB601473.1  85.089     731       102        7
# 11   8_S356_contig000021      AB601473.1  84.615     507        72        6
# 12   8_S356_contig000022      AB601473.1  86.826     668        87        1
# 13   8_S356_contig000023      AB601473.1  85.496     524        69        7
# 14   8_S356_contig000024      LT972196.1  87.770     139        17        0
# 15   8_S356_contig000025      JQ676168.1  89.958     239        18        1
# 16   8_S356_contig000026      CP020799.1  80.769     104        12        7
# 17   8_S356_contig000027      KX098545.1  92.733     344        20        3
# 19   8_S356_contig000028  XM_020778772.1  88.095      84        10        0
# 20   8_S356_contig000033  XM_015967717.1  81.522      92        10        5
# 21   8_S356_contig000034      AB780552.1  88.520     662        68        4
# 22   8_S356_contig000035      AB780552.1  88.114     631        66        5
# 23   8_S356_contig000036      JX993748.1  89.130     138        11        4
# 24   8_S356_contig000037      JX993748.1  89.781     137        11        3
# 25   8_S356_contig000038      JX993748.1  89.781     137        11        3
# 26   8_S356_contig000039      JX993748.1  89.781     137        11        3
# 27   8_S356_contig000040      JX993748.1  89.781     137        11        3
# 28   8_S356_contig000041      JX993748.1  89.781     137        11        3
# 29   8_S356_contig000042      JX993748.1  89.781     137        11        3
# 30   8_S356_contig000044  XM_005944092.1  92.857      56         4        0
# 31   8_S356_contig000046      AB780551.1  94.366      71         4        0
# 32   8_S356_contig000047      AB780553.1  89.474     342        36        0
# ..                   ...             ...     ...     ...       ...      ...
# 185  8_S356_contig000251      LN590691.1  88.732      71         8        0
# 186  8_S356_contig000252      JX306953.1  97.924     289         6        0
# 187  8_S356_contig000253  XM_005941944.2  89.787     235        23        1
# 188  8_S356_contig000254      CP020799.1  87.728     383        42        5
# 191  8_S356_contig000255  XM_019345319.1  91.935     186        13        2
# 192  8_S356_contig000258  XM_005454536.3  82.171     129        18        4
# 193  8_S356_contig000266  XM_013267727.2  86.567      67         8        1
# 194  8_S356_contig000272      LN590969.1  91.803      61         5        0
# 195  8_S356_contig000274      CP026253.1  95.455      44         2        0
# 196  8_S356_contig000275      EU008541.1  87.838     222        27        0
# 198  8_S356_contig000278  XR_002057775.1  97.436      39         1        0
# 199  8_S356_contig000281      LN593564.1  83.190     232        34        1
# 200  8_S356_contig000283      JF262086.1  80.198     101        13        4
# 201  8_S356_contig000284  XM_005735654.1  93.617      47         3        0
# 202  8_S356_contig000287  XM_003446966.4  87.692     130        16        0
# 203  8_S356_contig000291  XM_005451386.3  92.562     121         8        1
# 204  8_S356_contig000292      LN590695.1  93.857     293        17        1
# 229  8_S356_contig000295      KF146044.1  88.593     263        21        8
# 230  8_S356_contig000296  XM_019346557.1  88.028     142        13        2
# 231  8_S356_contig000297      CP020799.1  86.022      93        10        3
# 232  8_S356_contig000301  XM_019358896.1  82.249     169        27        2
# 233  8_S356_contig000303      KF056004.1  82.353     153        19        7
# 234  8_S356_contig000307  XR_002060534.1  93.878      49         2        1
# 235  8_S356_contig000308  XM_013999724.1  85.235     149        13        6
# 236  8_S356_contig000309  XR_001660667.1  94.389     303        17        0
# 237  8_S356_contig000313     BX005297.22  86.755     151        19        1
# 238  8_S356_contig000314  XM_014034085.1  97.436      78         2        0
# 239  8_S356_contig000315  XM_020623935.1  88.889      99        11        0
# 240  8_S356_contig000320  XM_019347398.1  92.969     128         9        0
# 241  8_S356_contig000321      CP020800.1  81.481     108        18        2
#
#      qstart  qend    sstart      send         evalue  bitscore sskingdoms  \
# 0       311   362       885       834   1.160000e-07      69.4  Eukaryota
# 1        74   207        52       185   5.430000e-52     215.0  Eukaryota
# 2        85   212        78       211   2.720000e-11      82.4  Eukaryota
# 3       190   357       781       615   1.930000e-48     204.0  Eukaryota
# 4        70   326  13254129  13253866   3.560000e-85     326.0  Eukaryota
# 7        60   162      6246      6145   3.980000e-34     156.0  Eukaryota
# 8        17   279      6243      5976   1.100000e-69     274.0  Eukaryota
# 9       213   636     38428     38848  7.910000e-105     392.0  Eukaryota
# 10        1   726     15423     14695   0.000000e+00     739.0  Eukaryota
# 11        1   504     15524     16027  3.230000e-137     499.0  Eukaryota
# 12        1   668     15361     16027   0.000000e+00     745.0  Eukaryota
# 13        3   523     16157     16676  2.330000e-149     540.0  Eukaryota
# 14        1   139  15545794  15545932   1.800000e-36     163.0  Eukaryota
# 15      106   338       594       832   2.420000e-78     303.0  Eukaryota
# 16       27   124  24330937  24330836   9.560000e-10      75.0  Eukaryota
# 17       21   359    114538    114881  3.690000e-135     492.0  Eukaryota
# 19      152   235      1689      1772   1.630000e-17     100.0  Eukaryota
# 20      148   236      1672      1759   6.790000e-08      69.4  Eukaryota
# 21      206   865    110976    110321   0.000000e+00     795.0  Eukaryota
# 22       65   692    110945    110321   0.000000e+00     741.0  Eukaryota
# 23      374   509       210        75   1.240000e-37     169.0  Eukaryota
# 24      215   349       210        75   6.520000e-39     172.0  Eukaryota
# 25      421   555       210        75   1.030000e-38     172.0  Eukaryota
# 26      215   349       210        75   6.560000e-39     172.0  Eukaryota
# 27      383   517       210        75   9.720000e-39     172.0  Eukaryota
# 28      373   507       210        75   9.550000e-39     172.0  Eukaryota
# 29      235   369       210        75   7.230000e-39     172.0  Eukaryota
# 30      114   169      3207      3262   5.890000e-12      82.4  Eukaryota
# 31       99   169     83665     83735   2.920000e-20     110.0  Eukaryota
# 32       99   440     25282     24941  2.840000e-117     433.0  Eukaryota
# ..      ...   ...       ...       ...            ...       ...        ...
# 185       1    71   2342201   2342131   2.520000e-13      87.9  Eukaryota
# 186     102   390         1       289  1.870000e-138     503.0  Eukaryota
# 187       5   238      1484      1250   1.520000e-77     300.0  Eukaryota
# 188       1   380  25588858  25588478  6.860000e-120     442.0  Eukaryota
# 191      65   248       938       753   2.700000e-65     259.0  Eukaryota
# 192     252   376      6624      6751   6.280000e-19     106.0  Eukaryota
# 193      27    92       679       613   4.460000e-09      73.1  Eukaryota
# 194      93   153    263443    263503   5.390000e-13      86.1  Eukaryota
# 195       6    49   3411499   3411542   1.160000e-08      71.3  Eukaryota
# 196       4   225    108889    108668   6.700000e-66     261.0  Eukaryota
# 198       3    41      2878      2840   1.550000e-07      67.6  Eukaryota
# 199       1   227     66343     66574   8.940000e-50     207.0  Eukaryota
# 200     138   232    153445    153544   8.490000e-08      69.4  Eukaryota
# 201       1    47      1402      1448   1.360000e-08      71.3  Eukaryota
# 202      84   213      1131      1002   3.940000e-33     152.0  Eukaryota
# 203     128   248      8009      7890   3.620000e-39     172.0  Eukaryota
# 204      46   337  16183032  16183324  1.320000e-119     440.0  Eukaryota
# 229      52   311       165       421   9.560000e-81     311.0  Eukaryota
# 230      68   205      1134      1275   5.120000e-37     165.0  Eukaryota
# 231      43   134  16904361  16904451   1.150000e-15      97.1  Eukaryota
# 232       2   167      2040      1872   3.770000e-30     143.0  Eukaryota
# 233      83   232      1940      2087   3.120000e-25     126.0  Eukaryota
# 234     260   308        48         1   6.600000e-09      73.1  Eukaryota
# 235     107   246      1833      1685   7.810000e-31     145.0  Eukaryota
# 236       1   303       468       166  1.850000e-127     466.0  Eukaryota
# 237     113   263    107931    108080   1.890000e-37     167.0  Eukaryota
# 238     175   252      2376      2453   2.520000e-27     134.0  Eukaryota
# 239       1    99      1010       912   3.450000e-24     122.0  Eukaryota
# 240       1   128      1289      1162   1.190000e-43     187.0  Eukaryota
# 241     135   240  25315154  25315047   1.420000e-13      87.9  Eukaryota
#
#                                                 stitle        staxids  \
# 0    PREDICTED: Poecilia mexicana uncharacterized L...          48701
# 1    PREDICTED: Poecilia latipinna uncharacterized ...          48699
# 2    PREDICTED: Maylandia zebra F-box protein 34 (f...         106582
# 3    PREDICTED: Seriola dumerili uncharacterized LO...          41447
# 4                   Scophthalmus maximus chromosome 16          52904
# 7    PREDICTED: Kryptolebias marmoratus cholinergic...          37003
# 8    PREDICTED: Kryptolebias marmoratus cholinergic...          37003
# 9    Oreochromis niloticus vasa gene for ATP-depend...           8128
# 10   Haplochromis chilotes DNA, contains part of re...         257977
# 11   Haplochromis chilotes DNA, contains part of re...         257977
# 12   Haplochromis chilotes DNA, contains part of re...         257977
# 13   Haplochromis chilotes DNA, contains part of re...         257977
# 14   Larimichthys crocea genome assembly, chromosom...         215358
# 15   Satanoperca jurupari haplotype 18 tyrosine kin...          81341
# 16            Oryzias latipes strain HNI chromosome 21           8090
# 17    Ctenopharyngodon idella ADAR2 gene, complete cds           7959
# 19   PREDICTED: Pogona vitticeps sulfotransferase f...         103695
# 20   PREDICTED: Nothobranchius furzeri guanine nucl...         105023
# 21   Haplochromis chilotes DNA, containing V2R gene...         257977
# 22   Haplochromis chilotes DNA, containing V2R gene...         257977
# 23   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 24   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 25   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 26   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 27   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 28   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 29   Symphysodon discus clone Sd30 satellite ONSAT ...         306559
# 30   PREDICTED: Haplochromis burtoni USP6 N-termina...           8153
# 31   Haplochromis chilotes DNA, containing V2R gene...         257977
# 32   Haplochromis chilotes DNA, containing V2R gene...         257977
# ..                                                 ...            ...
# 185  Cyprinus carpio genome assembly common carp ge...           7962
# 186  Herichthys minckleyi isolate Ch33Mol MinP3B06e...  247393;247396
# 187  PREDICTED: Haplochromis burtoni wiskott-Aldric...           8153
# 188           Oryzias latipes strain HNI chromosome 21           8090
# 191  PREDICTED: Oreochromis niloticus leucine-rich ...           8128
# 192  PREDICTED: Oreochromis niloticus laminin subun...           8128
# 193  PREDICTED: Oreochromis niloticus RAS guanyl re...           8128
# 194  Cyprinus carpio genome assembly common carp ge...           7962
# 195                 Scophthalmus maximus chromosome 11          52904
# 196  Salmo salar neurogranin, TIP41-like protein (T...           8030
# 198  PREDICTED: Oreochromis niloticus adenosylhomoc...           8128
# 199  Cyprinus carpio genome assembly common carp ge...           7962
# 200  Oreochromis niloticus clone BAC T4-024BG04 RH2...           8128
# 201  PREDICTED: Pundamilia nyererei polymeric immun...         303518
# 202  PREDICTED: Oreochromis niloticus Sox30 protein...           8128
# 203  PREDICTED: Oreochromis niloticus ring finger a...           8128
# 204  Cyprinus carpio genome assembly common carp ge...           7962
# 229  Herichthys tamasopoensis isolate Ctom marker M...         247396
# 230  PREDICTED: Oreochromis niloticus kelch domain ...           8128
# 231           Oryzias latipes strain HNI chromosome 21           8090
# 232  PREDICTED: Oreochromis niloticus von Willebran...           8128
# 233  Carassius auratus clone JE135 microsatellite s...           7957
# 234  PREDICTED: Oreochromis niloticus periaxin (LOC...           8128
# 235  PREDICTED: Austrofundulus limnaeus uncharacter...          52670
# 236  PREDICTED: Poecilia formosa uncharacterized LO...          48698
# 237  Zebrafish DNA sequence from clone CH211-271B8 ...           7955
# 238  PREDICTED: Austrofundulus limnaeus transmembra...          52670
# 239  PREDICTED: Monopterus albus laminin subunit ga...          43700
# 240  PREDICTED: Oreochromis niloticus RNA-binding p...           8128
# 241           Oryzias latipes strain HNI chromosome 22           8090
#
#                                          sscinames  \
# 0                                Poecilia mexicana
# 1                               Poecilia latipinna
# 2                                  Maylandia zebra
# 3                                 Seriola dumerili
# 4                             Scophthalmus maximus
# 7                          Kryptolebias marmoratus
# 8                          Kryptolebias marmoratus
# 9                            Oreochromis niloticus
# 10                           Haplochromis chilotes
# 11                           Haplochromis chilotes
# 12                           Haplochromis chilotes
# 13                           Haplochromis chilotes
# 14                             Larimichthys crocea
# 15                            Satanoperca jurupari
# 16                                 Oryzias latipes
# 17                         Ctenopharyngodon idella
# 19                                Pogona vitticeps
# 20                          Nothobranchius furzeri
# 21                           Haplochromis chilotes
# 22                           Haplochromis chilotes
# 23                              Symphysodon discus
# 24                              Symphysodon discus
# 25                              Symphysodon discus
# 26                              Symphysodon discus
# 27                              Symphysodon discus
# 28                              Symphysodon discus
# 29                              Symphysodon discus
# 30                            Haplochromis burtoni
# 31                           Haplochromis chilotes
# 32                           Haplochromis chilotes
# ..                                             ...
# 185                                Cyprinus carpio
# 186  Herichthys minckleyi;Herichthys tamasopoensis
# 187                           Haplochromis burtoni
# 188                                Oryzias latipes
# 191                          Oreochromis niloticus
# 192                          Oreochromis niloticus
# 193                          Oreochromis niloticus
# 194                                Cyprinus carpio
# 195                           Scophthalmus maximus
# 196                                    Salmo salar
# 198                          Oreochromis niloticus
# 199                                Cyprinus carpio
# 200                          Oreochromis niloticus
# 201                            Pundamilia nyererei
# 202                          Oreochromis niloticus
# 203                          Oreochromis niloticus
# 204                                Cyprinus carpio
# 229                       Herichthys tamasopoensis
# 230                          Oreochromis niloticus
# 231                                Oryzias latipes
# 232                          Oreochromis niloticus
# 233                              Carassius auratus
# 234                          Oreochromis niloticus
# 235                        Austrofundulus limnaeus
# 236                               Poecilia formosa
# 237                                    Danio rerio
# 238                        Austrofundulus limnaeus
# 239                               Monopterus albus
# 240                          Oreochromis niloticus
# 241                                Oryzias latipes
#
#                                          scomnames  sblastnames
# 0                                Poecilia mexicana  bony fishes
# 1                                    sailfin molly  bony fishes
# 2                                      zebra mbuna  bony fishes
# 3                                greater amberjack  bony fishes
# 4                                           turbot  bony fishes
# 7                                 mangrove rivulus  bony fishes
# 8                                 mangrove rivulus  bony fishes
# 9                                     Nile tilapia  bony fishes
# 10                           Haplochromis chilotes  bony fishes
# 11                           Haplochromis chilotes  bony fishes
# 12                           Haplochromis chilotes  bony fishes
# 13                           Haplochromis chilotes  bony fishes
# 14                            large yellow croaker  bony fishes
# 15                                demon eartheater  bony fishes
# 16                                 Japanese medaka  bony fishes
# 17                                      grass carp  bony fishes
# 19                          central bearded dragon      lizards
# 20                             turquoise killifish  bony fishes
# 21                           Haplochromis chilotes  bony fishes
# 22                           Haplochromis chilotes  bony fishes
# 23                              Symphysodon discus  bony fishes
# 24                              Symphysodon discus  bony fishes
# 25                              Symphysodon discus  bony fishes
# 26                              Symphysodon discus  bony fishes
# 27                              Symphysodon discus  bony fishes
# 28                              Symphysodon discus  bony fishes
# 29                              Symphysodon discus  bony fishes
# 30                           Burton's mouthbrooder  bony fishes
# 31                           Haplochromis chilotes  bony fishes
# 32                           Haplochromis chilotes  bony fishes
# ..                                             ...          ...
# 185                                    common carp  bony fishes
# 186  Herichthys minckleyi;Herichthys tamasopoensis  bony fishes
# 187                          Burton's mouthbrooder  bony fishes
# 188                                Japanese medaka  bony fishes
# 191                                   Nile tilapia  bony fishes
# 192                                   Nile tilapia  bony fishes
# 193                                   Nile tilapia  bony fishes
# 194                                    common carp  bony fishes
# 195                                         turbot  bony fishes
# 196                                Atlantic salmon  bony fishes
# 198                                   Nile tilapia  bony fishes
# 199                                    common carp  bony fishes
# 200                                   Nile tilapia  bony fishes
# 201                            Pundamilia nyererei  bony fishes
# 202                                   Nile tilapia  bony fishes
# 203                                   Nile tilapia  bony fishes
# 204                                    common carp  bony fishes
# 229                       Herichthys tamasopoensis  bony fishes
# 230                                   Nile tilapia  bony fishes
# 231                                Japanese medaka  bony fishes
# 232                                   Nile tilapia  bony fishes
# 233                                       goldfish  bony fishes
# 234                                   Nile tilapia  bony fishes
# 235                        Austrofundulus limnaeus  bony fishes
# 236                                   Amazon molly  bony fishes
# 237                                      zebrafish  bony fishes
# 238                        Austrofundulus limnaeus  bony fishes
# 239                                      swamp eel  bony fishes
# 240                                   Nile tilapia  bony fishes
# 241                                Japanese medaka  bony fishes
#
# [148 rows x 18 columns]

# %% [markdown]
# # Cuántos grupos hay a parte de peces?

# %%
ftab2= ftab1.groupby("sblastnames")["qseqid"].count()
ftab2 = DataFrame(ftab2)
ftab2
# Out:
#                qseqid
# sblastnames
# bony fishes       145
# frogs & toads       2
# lizards             1

# %%
ftab2= ftab1.groupby("sscinames")["qseqid"].count()
ftab2.sort_values(axis = 0, ascending=False, inplace=True)
ftab2
# Out:
# sscinames
# Oreochromis niloticus                                                  34
# Haplochromis chilotes                                                  15
# Cyprinus carpio                                                        12
# Haplochromis burtoni                                                   10
# Oryzias latipes                                                         8
# Symphysodon discus                                                      7
# Scophthalmus maximus                                                    6
# Maylandia zebra                                                         4
# Austrofundulus limnaeus                                                 4
# Neolamprologus brichardi                                                3
# Dicentrarchus labrax                                                    3
# Salmo salar                                                             3
# Kryptolebias marmoratus                                                 3
# Rana pipiens                                                            2
# Poecilia formosa                                                        2
# Nothobranchius furzeri                                                  2
# Pygocentrus nattereri                                                   2
# Larimichthys crocea                                                     2
# Poecilia mexicana                                                       2
# Herichthys carpintis;Herichthys minckleyi                               1
# Cichla kelberi                                                          1
# Herichthys cyanoguttatus;Herichthys tamasopoensis;Herichthys deppii     1
# Danio rerio                                                             1
# Herichthys minckleyi;Herichthys tamasopoensis                           1
# Herichthys tamasopoensis                                                1
# Carassius auratus                                                       1
# Ictalurus punctatus                                                     1
# Ctenopharyngodon idella                                                 1
# Xiphophorus maculatus                                                   1
# Lates calcarifer                                                        1
# Megalobrama amblycephala                                                1
# Monopterus albus                                                        1
# Xiphophorus hellerii                                                    1
# Poecilia latipinna                                                      1
# Poecilia reticulata                                                     1
# Pogona vitticeps                                                        1
# Pterophyllum scalare                                                    1
# Pundamilia nyererei                                                     1
# Rhinogobio ventralis                                                    1
# Satanoperca jurupari                                                    1
# Seriola dumerili                                                        1
# Sinocyclocheilus anshuiensis                                            1
# Nimbapanchax jeanpoli                                                   1
# Name: qseqid, dtype: int64

# %% [markdown]
# # procedimiento para simplificar tabla y graficar las 10 primeras categorías y el resto ponerlas en "otras"

# %%
linea10=ftab2[:10]
linea11=ftab2[10:]
#linea10
otro=sum (linea11)
#otro
otros = pd.DataFrame({0:otro}, index=["Other"])
otros
linea10=linea10.append(otros)
linea10
# Out:
#                            0
# Oreochromis niloticus     34
# Haplochromis chilotes     15
# Cyprinus carpio           12
# Haplochromis burtoni      10
# Oryzias latipes            8
# Symphysodon discus         7
# Scophthalmus maximus       6
# Maylandia zebra            4
# Austrofundulus limnaeus    4
# Neolamprologus brichardi   3
# Other                     45

# %%
linea10.plot(kind='barh', figsize= (8,6))
plt.axis([-1, max(linea10[0])+5, -1, 10.8], label=None)
plt.legend().set_visible(False)
plt.xlabel("Frecuencia")
plt.ylabel("Especies")
plt.title("Especies con resultado de blastn")
plt.show()
