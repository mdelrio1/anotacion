# %% [markdown]
# # Bitacora para el manejo de secuencias fasta y búsqueda basica de *Blastx*

# %% [markdown]
# ## Para el siguiente ejercicio es necesario tener el Blast+ instalado en la computadora
# https://www.ncbi.nlm.nih.gov/guide/data-software/

# %%
cd ~/Desktop/curso/data/exp710/
# Out:
# /Users/migueldelrio/Desktop/curso/data/exp710

# %%
ls
# Out:
# 710_transcritos.fasta* data/                  results/
# 710_transcritos.tab    gi*
# blastx_borrar.tab*     programs/

# %%
# %%bash
# export BLASTDB=~/Desktop/bigdata/
#
# date
# time blastx -query 710_transcritos.fasta -db uniprot_sprot \
# -out 710_transcritos.tab -evalue 1E-6 -max_target_seqs 1 \
# -num_threads 2 -outfmt "6 std stitle"
# date

# %%
# !head 710_transcritos.tab
# Out:
# 1001070759	sp|P46595|UBC4_SCHPO	87.611	113	14	0	7	345	1	113	2.10e-66	199	sp|P46595|UBC4_SCHPO Ubiquitin-conjugating enzyme E2 4 OS=Schizosaccharomyces pombe (strain 972 / ATCC 24843) OX=284812 GN=ubc4 PE=1 SV=1
# 1001070758	sp|Q9Y4A8|NF2L3_HUMAN	43.243	111	61	1	1031	1357	536	646	2.04e-14	80.1	sp|Q9Y4A8|NF2L3_HUMAN Nuclear factor erythroid 2-related factor 3 OS=Homo sapiens OX=9606 GN=NFE2L3 PE=1 SV=1
# 1001070756	sp|P22813|HSF_DROME	44.286	70	39	0	621	830	164	233	9.36e-14	75.1	sp|P22813|HSF_DROME Heat shock factor protein OS=Drosophila melanogaster OX=7227 GN=Hsf PE=1 SV=1
# 1001070755	sp|P02833|ANTP_DROME	90.361	83	4	1	1185	1421	283	365	4.00e-41	157	sp|P02833|ANTP_DROME Homeotic protein antennapedia OS=Drosophila melanogaster OX=7227 GN=Antp PE=1 SV=1
# 1001070754	sp|G5E8K5|ANK3_MOUSE	25.131	382	203	13	434	1498	352	677	1.78e-12	76.3	sp|G5E8K5|ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754	sp|G5E8K5|ANK3_MOUSE	33.077	130	78	3	386	775	469	589	1.43e-10	70.1	sp|G5E8K5|ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754	sp|G5E8K5|ANK3_MOUSE	28.926	121	78	2	419	781	644	756	3.90e-07	58.9	sp|G5E8K5|ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754	sp|G5E8K5|ANK3_MOUSE	24.384	406	234	14	434	1486	253	640	4.32e-07	58.5	sp|G5E8K5|ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754	sp|G5E8K5|ANK3_MOUSE	29.508	122	78	2	416	781	544	657	9.96e-07	57.4	sp|G5E8K5|ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070753	sp|P05179|CP2C7_RAT	32.653	441	270	8	249	1520	58	488	1.20e-65	223	sp|P05179|CP2C7_RAT Cytochrome P450 2C7 OS=Rattus norvegicus OX=10116 GN=Cyp2c7 PE=1 SV=2

# %%
from pandas import Series, DataFrame
import pandas as pd
from Bio import SeqIO, AlignIO, SeqRecord
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
import matplotlib.pyplot as plt 
import os
#from matplotlib_venn import venn3_unweighted

# %% [markdown]
# ###  Blastx da los resultados sin nombre de columnas, por lo que se asignan a la variable "encabezado".
# ### *NOTA:* el blastx a la base de datos swissprot da como segunda columna el identificador de Uniprot y no el del GenBank como en el caso de blastn a la base de datos 16 microbial o nt

# %%
# observe el nombre de la segunda columna
encabezado =("qseqid", "sp", "uniprotid", "uniprotid2", "pident", "length", "mismatch", "gapopen","qstart",
             "qend", "sstart","send", "evalue", "bitscore", "stitle")

# %% [markdown]
# ### cambiando el archivo de tab a csv

# %%
f = open ("710_transcritos.tab", 'r')
f_out= open("710_transcritos.csv",'w')
# if you want to add the column name from the blast ftm, to the csv output, eliminate the "#" in the next line
f_out.write('qseqid,sseqid-1,uniprotid,sseqid-3,pident,length,mismatch,gapopen,qstart,qend,sstart,send,evalue,bitscore,stitle_sp,uniprotid2,stitle,stitle_2'+"\n")
n=0
for line in f.readlines():
    line1 = line.replace("|","\t")
    line1 = line1.replace("\t", ",")
    f_out.write(line1)
    n=n+1

f_out.close()
f.close()
print (str(n)+" sequences processed")
# Out:
# 1324 sequences processed

# %%
# !head 710_transcritos.csv
# Out:
# qseqid,sseqid-1,uniprotid,sseqid-3,pident,length,mismatch,gapopen,qstart,qend,sstart,send,evalue,bitscore,stitle_sp,uniprotid2,stitle,stitle_2
# 1001070759,sp,P46595,UBC4_SCHPO,87.611,113,14,0,7,345,1,113,2.10e-66,199,sp,P46595,UBC4_SCHPO Ubiquitin-conjugating enzyme E2 4 OS=Schizosaccharomyces pombe (strain 972 / ATCC 24843) OX=284812 GN=ubc4 PE=1 SV=1
# 1001070758,sp,Q9Y4A8,NF2L3_HUMAN,43.243,111,61,1,1031,1357,536,646,2.04e-14,80.1,sp,Q9Y4A8,NF2L3_HUMAN Nuclear factor erythroid 2-related factor 3 OS=Homo sapiens OX=9606 GN=NFE2L3 PE=1 SV=1
# 1001070756,sp,P22813,HSF_DROME,44.286,70,39,0,621,830,164,233,9.36e-14,75.1,sp,P22813,HSF_DROME Heat shock factor protein OS=Drosophila melanogaster OX=7227 GN=Hsf PE=1 SV=1
# 1001070755,sp,P02833,ANTP_DROME,90.361,83,4,1,1185,1421,283,365,4.00e-41,157,sp,P02833,ANTP_DROME Homeotic protein antennapedia OS=Drosophila melanogaster OX=7227 GN=Antp PE=1 SV=1
# 1001070754,sp,G5E8K5,ANK3_MOUSE,25.131,382,203,13,434,1498,352,677,1.78e-12,76.3,sp,G5E8K5,ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754,sp,G5E8K5,ANK3_MOUSE,33.077,130,78,3,386,775,469,589,1.43e-10,70.1,sp,G5E8K5,ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754,sp,G5E8K5,ANK3_MOUSE,28.926,121,78,2,419,781,644,756,3.90e-07,58.9,sp,G5E8K5,ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754,sp,G5E8K5,ANK3_MOUSE,24.384,406,234,14,434,1486,253,640,4.32e-07,58.5,sp,G5E8K5,ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1
# 1001070754,sp,G5E8K5,ANK3_MOUSE,29.508,122,78,2,416,781,544,657,9.96e-07,57.4,sp,G5E8K5,ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 GN=Ank3 PE=1 SV=1

# %% [markdown]
# ### Se lee el archivo de salida y se asigna a la variable "ftab", con ello se pueden ver los resultados

# %%
ftab=pd.read_csv("710_transcritos.csv", header=0,
                  engine='python')
ftab.head()
# Out:
#        qseqid sseqid-1 uniprotid     sseqid-3  pident  length  mismatch  \
# 0  1001070759       sp    P46595   UBC4_SCHPO  87.611     113        14
# 1  1001070758       sp    Q9Y4A8  NF2L3_HUMAN  43.243     111        61
# 2  1001070756       sp    P22813    HSF_DROME  44.286      70        39
# 3  1001070755       sp    P02833   ANTP_DROME  90.361      83         4
# 4  1001070754       sp    G5E8K5   ANK3_MOUSE  25.131     382       203
#
#    gapopen  qstart  qend  sstart  send        evalue  bitscore stitle_sp  \
# 0        0       7   345       1   113  2.100000e-66     199.0        sp
# 1        1    1031  1357     536   646  2.040000e-14      80.1        sp
# 2        0     621   830     164   233  9.360000e-14      75.1        sp
# 3        1    1185  1421     283   365  4.000000e-41     157.0        sp
# 4       13     434  1498     352   677  1.780000e-12      76.3        sp
#
#   uniprotid2                                             stitle stitle_2
# 0     P46595  UBC4_SCHPO Ubiquitin-conjugating enzyme E2 4 O...     None
# 1     Q9Y4A8  NF2L3_HUMAN Nuclear factor erythroid 2-related...     None
# 2     P22813  HSF_DROME Heat shock factor protein OS=Drosoph...     None
# 3     P02833  ANTP_DROME Homeotic protein antennapedia OS=Dr...     None
# 4     G5E8K5  ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 ...     None

# %%
n=0
especie=[]
for row in ftab.index:
    row2=ftab.loc[row]
    try :
        row2["stitle"].find("OS=")
    except:
        linea=row2["stitle_2"][row2["stitle_2"].find("OS=")+3:row2["stitle_2"].find("OX=")]
        print (linea)
        especie.append(linea)

    else:
        linea=row2["stitle"][row2["stitle"].find("OS=")+3:row2["stitle"].find("OX=")]
        print (linea)
        especie.append(linea)
        
    n+=1
    #if n==10:
    #    break
especie[:5]
# Out:
# Schizosaccharomyces pombe (strain 972 / ATCC 24843)
# Homo sapiens
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Rattus norvegicus
# Mus musculus
# Gallus gallus
# Mus musculus
# Xenopus laevis
# Drosophila melanogaster
# Drosophila melanogaster
# Xenopus tropicalis
# Xenopus tropicalis
# Xenopus tropicalis
# Mus musculus
# Homo sapiens
# Anopheles albimanus
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# T1C_ANOGA Glutathione S-transferase
# T1C_ANOGA Glutathione S-transferase
# T1C_ANOGA Glutathione S-transferase
# T1C_ANOGA Glutathione S-transferase
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Danio rerio
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Rattus norvegicus
# Rattus norvegicus
# Homo sapiens
# Mus musculus
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Pongo abelii
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila pseudoobscura pseudoobscura
# Drosophila melanogaster
# Mus musculus
# Gallus gallus
# Gallus gallus
# Gallus gallus
# Gallus gallus
# Gallus gallus
# Xenopus laevis
# Sus scrofa
# Diploptera punctata
# LK_RABIT Myosin light chain kinas
# LK_RABIT Myosin light chain kinas
# Xenopus tropicalis
# Mus musculus
# Spodoptera frugiperda
# Drosophila melanogaster
# Serinus canaria
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Cydia pomonella granulosis virus (isolate Mexico/1963)
# Cydia pomonella granulosis virus (isolate Mexico/1963)
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Mus musculus
# Caenorhabditis elegans
# Homo sapiens
# Gallus gallus
# Gallus gallus
# Gallus gallus
# 315_DROME Cytochrome P450 315a
# Musca domestica
# Musca domestica
# Drosophila melanogaster
# SL_RAT Glutaminase liver isofor
# SL_RAT Glutaminase liver isofor
# SL_RAT Glutaminase liver isofor
# SK_MOUSE Glutaminase kidney isofor
# Caenorhabditis elegans
# Caenorhabditis elegans
# SL_RAT Glutaminase liver isofor
# Caenorhabditis elegans
# Caenorhabditis elegans
# Mus musculus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Caenorhabditis elegans
# S_RHOPR Nitric oxide synthas
# Danio rerio
# Drosophila melanogaster
# Drosophila melanogaster
# Gallus gallus
# Gallus gallus
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Rickettsia felis (strain ATCC VR-1525 / URRWXCal2)
# Drosophila melanogaster
# Rattus norvegicus
# Rattus norvegicus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Bos taurus
# Bos taurus
# Bos taurus
# Bos taurus
# Bos taurus
# Gallus gallus
# Gallus gallus
# Squalus acanthias
# Oryzias latipes
# Gallus gallus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Poeciliopsis lucida
# Poeciliopsis lucida
# Bos taurus
# Bos taurus
# Bos taurus
# Bos taurus
# Drosophila melanogaster
# Drosophila melanogaster
# Gallus gallus
# Squalus acanthias
# Gallus gallus
# Rattus norvegicus
# Oryzias latipes
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Caenorhabditis elegans
# Oryctolagus cuniculus
# Caenorhabditis elegans
# 61_RAT 6-phosphofructo-2-kinase/fructose-
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Caenorhabditis elegans
# Coturnix japonica
# Coturnix japonica
# Spodoptera frugiperda
# Homo sapiens
# Xenopus tropicalis
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# 100_BOVIN Protein PET100 homolo
# Homo sapiens
# Homo sapiens
# 100_BOVIN Protein PET100 homolo
# 100_BOVIN Protein PET100 homolo
# Pongo abelii
# Pongo abelii
# Pongo abelii
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Bos taurus
# Bos taurus
# Mus musculus
# Mus musculus
# Mus musculus
# Homo sapiens
# 100_BOVIN Protein PET100 homolo
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Mus musculus
# Mus musculus
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Homo sapiens
# Mus musculus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Caenorhabditis elegans
# Blaberus discoidalis
# Mus musculus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Rattus norvegicus
# Rattus norvegicus
# Ascaris suum
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Homo sapiens
# 2A5_DROME Probable cytochrome P450 12a
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Mus musculus
# Gallus gallus
# LK_RABIT Myosin light chain kinas
# LK_RABIT Myosin light chain kinas
# Drosophila melanogaster
# Homo sapiens
# Drosophila melanogaster
# Kluyveromyces lactis (strain ATCC 8585 / CBS 2359 / DSM 70799 / NBRC 1267 / NRRL Y-1140 / WM37)
# Arabidopsis thaliana
# Kluyveromyces lactis (strain ATCC 8585 / CBS 2359 / DSM 70799 / NBRC 1267 / NRRL Y-1140 / WM37)
# Arabidopsis thaliana
# Kluyveromyces lactis (strain ATCC 8585 / CBS 2359 / DSM 70799 / NBRC 1267 / NRRL Y-1140 / WM37)
# Arabidopsis thaliana
# Manduca sexta
# Mus musculus
# Bos taurus
# Bos taurus
# Bos taurus
# Caenorhabditis elegans
# Drosophila melanogaster
# Columba livia
# Columba livia
# Columba livia
# Columba livia
# I2_HUMAN Enoyl-CoA delta isomerase
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Homo sapiens
# Bos taurus
# Bos taurus
# Xenopus laevis
# Drosophila melanogaster
# Drosophila melanogaster
# Xenopus laevis
# Drosophila melanogaster
# Drosophila melanogaster
# Bos taurus
# Homo sapiens
# Drosophila melanogaster
# Rattus norvegicus
# Homo sapiens
# Xenopus laevis
# Xenopus laevis
# Bos taurus
# Rattus norvegicus
# Rattus norvegicus
# Rattus norvegicus
# Mus musculus
# Drosophila melanogaster
# Mus musculus
# Rattus norvegicus
# Mus musculus
# Homo sapiens
# Homo sapiens
# Xenopus laevis
# Xenopus laevis
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Drosophila melanogaster
# Musca domestica
# Gorilla gorilla gorilla
# Drosophila melanogaster
# Gorilla gorilla gorilla
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Lucilia cuprina
# Xenopus laevis
# Drosophila melanogaster
# Mus musculus
# Spodoptera frugiperda
# Caenorhabditis elegans
# Spodoptera frugiperda
# Mus musculus
# Mus musculus
# Mus musculus
# Drosophila melanogaster
# Canis lupus familiaris
# Blattella germanica
# Rattus norvegicus
# Rattus norvegicus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Rattus norvegicus
# Rattus norvegicus
# Drosophila melanogaster
# Drosophila melanogaster
# Rattus norvegicus
# Homo sapiens
# Homo sapiens
# Danio rerio
# P25_DROME cGMP-dependent protein kinas
# P25_DROME cGMP-dependent protein kinas
# P25_DROME cGMP-dependent protein kinas
# P25_DROME cGMP-dependent protein kinas
# Mus musculus
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Drosophila melanogaster
# Mus musculus
# Mus musculus
# Drosophila melanogaster
# Xenopus laevis
# Drosophila melanogaster
# Drosophila melanogaster
# Diploptera punctata
# Pyrenomonas salina
# BCH_CHICK 3-hydroxyisobutyryl-CoA hydrolas
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Bos taurus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Mus musculus
# Serinus canaria
# Caenorhabditis elegans
# Rattus norvegicus
# Bos taurus
# Homo sapiens
# Homo sapiens
# Diploptera punctata
# Rattus norvegicus
# Mus musculus
# Bos taurus
# Drosophila melanogaster
# Homo sapiens
# Mus musculus
# Mus musculus
# Mus musculus
# S_RHOPR Nitric oxide synthas
# S1_MOUSE Nitric oxide synthas
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Artemia franciscana
# Artemia franciscana
# Artemia franciscana
# Artemia franciscana
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# Homo sapiens
# ['Schizosaccharomyces pombe (strain 972 / ATCC 24843) ',
#  'Homo sapiens ',
#  'Drosophila melanogaster ',
#  'Drosophila melanogaster ',
#  'Mus musculus ']

# %%
ftab["especie"]=especie
ftab.head()
# Out:
#        qseqid sseqid-1 uniprotid     sseqid-3  pident  length  mismatch  \
# 0  1001070759       sp    P46595   UBC4_SCHPO  87.611     113        14
# 1  1001070758       sp    Q9Y4A8  NF2L3_HUMAN  43.243     111        61
# 2  1001070756       sp    P22813    HSF_DROME  44.286      70        39
# 3  1001070755       sp    P02833   ANTP_DROME  90.361      83         4
# 4  1001070754       sp    G5E8K5   ANK3_MOUSE  25.131     382       203
#
#    gapopen  qstart  qend  sstart  send        evalue  bitscore stitle_sp  \
# 0        0       7   345       1   113  2.100000e-66     199.0        sp
# 1        1    1031  1357     536   646  2.040000e-14      80.1        sp
# 2        0     621   830     164   233  9.360000e-14      75.1        sp
# 3        1    1185  1421     283   365  4.000000e-41     157.0        sp
# 4       13     434  1498     352   677  1.780000e-12      76.3        sp
#
#   uniprotid2                                             stitle stitle_2  \
# 0     P46595  UBC4_SCHPO Ubiquitin-conjugating enzyme E2 4 O...     None
# 1     Q9Y4A8  NF2L3_HUMAN Nuclear factor erythroid 2-related...     None
# 2     P22813  HSF_DROME Heat shock factor protein OS=Drosoph...     None
# 3     P02833  ANTP_DROME Homeotic protein antennapedia OS=Dr...     None
# 4     G5E8K5  ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 ...     None
#
#                                              especie
# 0  Schizosaccharomyces pombe (strain 972 / ATCC 2...
# 1                                      Homo sapiens
# 2                           Drosophila melanogaster
# 3                           Drosophila melanogaster
# 4                                      Mus musculus

# %%
ftab.tail()
# Out:
#           qseqid sseqid-1 uniprotid     sseqid-3  pident  length  mismatch  \
# 1319  1001070050       sp    Q8NB50  ZFP62_HUMAN  45.283      53        23
# 1320  1001070050       sp    Q8NB50  ZFP62_HUMAN  25.188     532       314
# 1321  1001070050       sp    Q8NB50  ZFP62_HUMAN  42.105      57        26
# 1322  1001070050       sp    Q8NB50  ZFP62_HUMAN  27.248     367       182
# 1323  1001070050       sp    Q8NB50  ZFP62_HUMAN  26.667     360       222
#
#       gapopen  qstart  qend  sstart  send        evalue  bitscore stitle_sp  \
# 1319        3    2151  2303     647   695  3.830000e-14      35.0        sp
# 1320       20     584  2032     198   694  2.510000e-13      70.1        sp
# 1321        4    2151  2315     731   782  2.510000e-13      28.5        sp
# 1322       13     983  2032     563   861  1.370000e-11      72.4        sp
# 1323       12     983  2032     479   806  2.430000e-11      71.2        sp
#
#      uniprotid2                                             stitle stitle_2  \
# 1319     Q8NB50  ZFP62_HUMAN Zinc finger protein 62 homolog OS=...     None
# 1320     Q8NB50  ZFP62_HUMAN Zinc finger protein 62 homolog OS=...     None
# 1321     Q8NB50  ZFP62_HUMAN Zinc finger protein 62 homolog OS=...     None
# 1322     Q8NB50  ZFP62_HUMAN Zinc finger protein 62 homolog OS=...     None
# 1323     Q8NB50  ZFP62_HUMAN Zinc finger protein 62 homolog OS=...     None
#
#             especie
# 1319  Homo sapiens
# 1320  Homo sapiens
# 1321  Homo sapiens
# 1322  Homo sapiens
# 1323  Homo sapiens

# %%
ftab1= ftab.groupby("especie")["qseqid"].count()
ftab1 = DataFrame(ftab1)
ftab1
# Out:
#                                                     qseqid
# especie
# 100_BOVIN Protein PET100 homolo                          4
# 2A5_DROME Probable cytochrome P450 12a                   1
# 315_DROME Cytochrome P450 315a                           1
# 61_RAT 6-phosphofructo-2-kinase/fructose-                1
# Anopheles albimanus                                      1
# Arabidopsis thaliana                                     3
# Artemia franciscana                                      4
# Ascaris suum                                             1
# BCH_CHICK 3-hydroxyisobutyryl-CoA hydrolas               1
# Blaberus discoidalis                                     1
# Blattella germanica                                      1
# Bos taurus                                              21
# Caenorhabditis elegans                                  13
# Canis lupus familiaris                                   1
# Columba livia                                            4
# Coturnix japonica                                        2
# Cydia pomonella granulosis virus (isolate Mexic...       2
# Danio rerio                                              3
# Diploptera punctata                                      3
# Drosophila melanogaster                                218
# Drosophila pseudoobscura pseudoobscura                   1
# Gallus gallus                                           17
# Gorilla gorilla gorilla                                  2
# Homo sapiens                                           784
# I2_HUMAN Enoyl-CoA delta isomerase                       1
# Kluyveromyces lactis (strain ATCC 8585 / CBS 23...       3
# LK_RABIT Myosin light chain kinas                        4
# Lucilia cuprina                                          1
# Manduca sexta                                            1
# Mus musculus                                           121
# Musca domestica                                          3
# Oryctolagus cuniculus                                    1
# Oryzias latipes                                          2
# P25_DROME cGMP-dependent protein kinas                   4
# Poeciliopsis lucida                                      2
# Pongo abelii                                             4
# Pyrenomonas salina                                       1
# Rattus norvegicus                                       41
# Rickettsia felis (strain ATCC VR-1525 / URRWXCa...       8
# S1_MOUSE Nitric oxide synthas                            1
# SK_MOUSE Glutaminase kidney isofor                       1
# SL_RAT Glutaminase liver isofor                          4
# S_RHOPR Nitric oxide synthas                             2
# Schizosaccharomyces pombe (strain 972 / ATCC 24...       1
# Serinus canaria                                          2
# Spodoptera frugiperda                                    4
# Squalus acanthias                                        2
# Sus scrofa                                               1
# T1C_ANOGA Glutathione S-transferase                      4
# Xenopus laevis                                          10
# Xenopus tropicalis                                       5

# %%
ftab1 = ftab.drop_duplicates(subset = "qseqid", inplace = False)
ftab1.describe().round(3)
# Out:
#              qseqid   pident    length  mismatch  gapopen    qstart      qend  \
# count  4.390000e+02  439.000   439.000   439.000  439.000   439.000   439.000
# mean   1.001070e+09   52.885   255.916   113.237    3.376   853.961   849.854
# std    1.979230e+02   18.030   211.558   106.592    4.012  1052.830   908.053
# min    1.001070e+09   22.751    37.000     4.000    0.000     1.000     1.000
# 25%    1.001070e+09   36.607   109.000    42.000    0.000   137.000   242.500
# 50%    1.001070e+09   49.315   185.000    75.000    2.000   434.000   567.000
# 75%    1.001071e+09   65.678   336.000   136.000    4.000  1139.000  1179.000
# max    1.001071e+09   95.238  1130.000   634.000   19.000  6725.000  5499.000
#
#          sstart      send  evalue  bitscore
# count   439.000   439.000   439.0   439.000
# mean    213.018   460.957     0.0   245.444
# std     405.448   432.854     0.0   203.528
# min       1.000    49.000     0.0    34.700
# 25%      12.000   200.000     0.0    89.000
# 50%      58.000   341.000     0.0   177.000
# 75%     230.000   547.000     0.0   325.000
# max    2302.000  2688.000     0.0  1066.000

# %%
ftab2= ftab1.groupby("especie")["qseqid"].count()
ftab2 = DataFrame(ftab2)
ftab2
# Out:
#                                                     qseqid
# especie
# 100_BOVIN Protein PET100 homolo                          4
# 2A5_DROME Probable cytochrome P450 12a                   1
# 315_DROME Cytochrome P450 315a                           1
# 61_RAT 6-phosphofructo-2-kinase/fructose-                1
# Anopheles albimanus                                      1
# Arabidopsis thaliana                                     3
# Artemia franciscana                                      4
# Ascaris suum                                             1
# BCH_CHICK 3-hydroxyisobutyryl-CoA hydrolas               1
# Blaberus discoidalis                                     1
# Blattella germanica                                      1
# Bos taurus                                              13
# Caenorhabditis elegans                                  13
# Canis lupus familiaris                                   1
# Columba livia                                            4
# Coturnix japonica                                        2
# Cydia pomonella granulosis virus (isolate Mexic...       1
# Danio rerio                                              3
# Diploptera punctata                                      3
# Drosophila melanogaster                                115
# Drosophila pseudoobscura pseudoobscura                   1
# Gallus gallus                                           17
# Gorilla gorilla gorilla                                  2
# Homo sapiens                                            83
# I2_HUMAN Enoyl-CoA delta isomerase                       1
# Kluyveromyces lactis (strain ATCC 8585 / CBS 23...       3
# LK_RABIT Myosin light chain kinas                        4
# Lucilia cuprina                                          1
# Manduca sexta                                            1
# Mus musculus                                            60
# Musca domestica                                          3
# Oryctolagus cuniculus                                    1
# Oryzias latipes                                          2
# P25_DROME cGMP-dependent protein kinas                   4
# Poeciliopsis lucida                                      1
# Pongo abelii                                             2
# Pyrenomonas salina                                       1
# Rattus norvegicus                                       40
# Rickettsia felis (strain ATCC VR-1525 / URRWXCa...       1
# S1_MOUSE Nitric oxide synthas                            1
# SK_MOUSE Glutaminase kidney isofor                       1
# SL_RAT Glutaminase liver isofor                          4
# S_RHOPR Nitric oxide synthas                             2
# Schizosaccharomyces pombe (strain 972 / ATCC 24...       1
# Serinus canaria                                          2
# Spodoptera frugiperda                                    4
# Squalus acanthias                                        2
# Sus scrofa                                               1
# T1C_ANOGA Glutathione S-transferase                      4
# Xenopus laevis                                          10
# Xenopus tropicalis                                       5

# %% [raw]
# ftab1= ftab.groupby("stitle")["qseqid"].count()
# ftab1 = DataFrame(ftab1)
# ftab1

# %% [raw]
# ftab=pd.read_table("710_transcritos.tab", header=None , names= encabezado,
#                   header=None, delimiter='\t|\|', engine='python')
# ftab.head()

# %% [raw]
# ftab1= ftab.groupby("stitle")["qseqid"].count()
# ftab1 = DataFrame(ftab1)
# ftab1

# %% [raw]
# ftab1= ftab.groupby("stitle")["qseqid"].count()
# ftab1 = DataFrame(ftab1)
# ftab1

# %% [raw]
# ftab1 = ftab.drop_duplicates(subset = "qseqid", inplace = False)
# ftab1.describe().round(3)

# %%
encabezadospid= ("uniprotid", "go")

# %%
fspid = pd.read_table('data/slim.txt', header= None, names= encabezadospid, delimiter="\t", engine="python")
fspid.head(2)
# Out:
#     uniprotid          go
# 0  A0A023PZB3  GO:0005739
# 1  A0A023PZB3  GO:0005739

# %%
ftab1.head()
# Out:
#        qseqid sseqid-1 uniprotid     sseqid-3  pident  length  mismatch  \
# 0  1001070759       sp    P46595   UBC4_SCHPO  87.611     113        14
# 1  1001070758       sp    Q9Y4A8  NF2L3_HUMAN  43.243     111        61
# 2  1001070756       sp    P22813    HSF_DROME  44.286      70        39
# 3  1001070755       sp    P02833   ANTP_DROME  90.361      83         4
# 4  1001070754       sp    G5E8K5   ANK3_MOUSE  25.131     382       203
#
#    gapopen  qstart  qend  sstart  send        evalue  bitscore stitle_sp  \
# 0        0       7   345       1   113  2.100000e-66     199.0        sp
# 1        1    1031  1357     536   646  2.040000e-14      80.1        sp
# 2        0     621   830     164   233  9.360000e-14      75.1        sp
# 3        1    1185  1421     283   365  4.000000e-41     157.0        sp
# 4       13     434  1498     352   677  1.780000e-12      76.3        sp
#
#   uniprotid2                                             stitle stitle_2  \
# 0     P46595  UBC4_SCHPO Ubiquitin-conjugating enzyme E2 4 O...     None
# 1     Q9Y4A8  NF2L3_HUMAN Nuclear factor erythroid 2-related...     None
# 2     P22813  HSF_DROME Heat shock factor protein OS=Drosoph...     None
# 3     P02833  ANTP_DROME Homeotic protein antennapedia OS=Dr...     None
# 4     G5E8K5  ANK3_MOUSE Ankyrin-3 OS=Mus musculus OX=10090 ...     None
#
#                                              especie
# 0  Schizosaccharomyces pombe (strain 972 / ATCC 2...
# 1                                      Homo sapiens
# 2                           Drosophila melanogaster
# 3                           Drosophila melanogaster
# 4                                      Mus musculus

# %%
f2=pd.merge(ftab1,fspid, on ="uniprotid", how='inner')
f2.head(2)
# Out:
# Empty DataFrame
# Columns: [qseqid, sseqid-1, uniprotid, sseqid-3, pident, length, mismatch, gapopen, qstart, qend, sstart, send, evalue, bitscore, stitle_sp, uniprotid2, stitle, stitle_2, especie, go]
# Index: []

# %%
fspid = ''
fspid

# %%
# !date

# %%
# !date

# %%
# !date
fgo = pd.read_csv('~/Desktop/bigdata/go_to_goslim.csv', engine="python")
fgo.head(2)

# %%
# !date

# %%
f3=pd.merge(f2,fgo, on ="GO_id" , how='inner')
f3.head()

# %%
# !date

# %%
f4=f3.drop_duplicates(subset = ('qseqid', "aspect"), inplace = False)
f4.describe()[['length','evalue']]

# %%
f4.to_csv("710_transcritos_goslim.csv", index =  None)

# %%
ftabpivot = f4.pivot_table(values="uniprotid" , index=["qseqid"], aggfunc=len, columns="aspect")
ftabpivot.describe()

# %% [markdown]
# # Proceso para generar el diagama de Venn con la información de
# ## Componentes celulares, funciones biologicas y procesos biologicos, C, F y P, respectivamente

# %%
lineaC =[] # data from C
lineaF =[] # data from F
lineaP =[] # data from P
linea = ""
n=1
for row in ftabpivot.index:
    row2=ftabpivot.loc[row]
    if str(row2["C"])=="nan" and str(row2["F"])=="nan" and str(row2["P"])=="nan" :
        continue    
    else:        
        if str(row2["C"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaC.append(linea)
        if str(row2["F"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaF.append(linea)

        if str(row2["P"]) !="nan":
            linea = row
        else:
            linea = ""
        lineaP.append(linea)

        n+=1
        #if n==1000:
        #    break

len(lineaC), len(lineaF), len(lineaP)

# %%
lineaC = set(lineaC)
lineaF = set(lineaF)
lineaP = set(lineaP)
venn3_unweighted([lineaC, lineaF, lineaP], ('C', 'F', 'P'))
plt.savefig("710_transcritos_venn3_1.png", dpi=400, bbox_inches='tight')
plt.savefig("710_transcritos_venn3_1.pdf", dpi=400, bbox_inches='tight')
plt.show()

# %%
fgo=f4.groupby('GOSlim_bin')["qseqid"].count()
#fgo

fgo.sort_values(inplace = True, ascending=False)
#fgo

linea10=fgo[0:10]
linea11=fgo[10:]
#linea10

#linea11
otro=sum (linea11)
#otro
otros = pd.DataFrame({0:otro}, index=["Other"])
#otros
linea10=linea10.append(otros)
#linea10
linea10.plot(kind='barh', color=list('ybg'))
plt.axis([-1, 500, -1, 11], label=None)
plt.xlabel("Count")
plt.ylabel("GOSlim bin")
plt.legend().set_visible(False)
#plt.savefig("710transcritos_blastx_GObar.png", dpi=400, bbox_inches='tight')


plt.show()
